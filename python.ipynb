# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejas7919-bit/DSA_6/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
print("Welcome to Data Analytics,", name + "!")
# Out:
# Enter your name: sreethi
# Welcome to Data Analytics, sreethi!

# %%
snack = "Chips"
print("I love munching on", snack, "during meetings!")
# Out:
# I love munching on Chips during meetings!

# %%
tasks = 15
next_week = tasks * 2
print("Expected tasks next week:", next_week)
# Out:
# Expected tasks next week: 30

# %%
income = 50000
expenses = 32000

savings = income - expenses

print("Savings =", savings)
# Out:
# Savings = 18000

# %%
friends = 8
bags_per_friend = 2

total = friends * bags_per_friend

print("Total popcorn bags =", total)
# Out:
# Total popcorn bags = 16

# %%
rating = int(input("Enter rating (1-5): "))

if rating > 3:
    print("Excellent Product!")
else:
    print("Average Product")
# Out:
# Enter rating (1-5): 6
# Excellent Product!

# %%
month1 = 50
month2 = 75
month3 = 100

average = (month1 + month2 + month3) / 3

print("Average Sales =", average)
# Out:
# Average Sales = 75.0

# %%
principal = 500
rate = 4
time = 3

interest = (principal * rate * time) / 100

total = principal + interest

print("Total Amount =", total)
# Out:
# Total Amount = 560.0

# %%
import math

guests = 10
slices_per_guest = 1
slices_per_cake = 8

cakes = math.ceil((guests * slices_per_guest) / slices_per_cake)

print("Cakes needed =", cakes)
# Out:
# Cakes needed = 2

# %%
text = "Data Analytics"

if len(text) > 10:
    print("Long slogan!")
else:
    print("Short slogan!")
# Out:
# Long slogan!

# %%
product_A_sales = 250
product_B_sales = 300

if product_A_sales > product_B_sales:
    print("Product A sold more.")
else:
    print("Product B sold more.")
# Out:
# Product B sold more.

# %%
scholarship = 750
total = 1000

percentage = (scholarship / total) * 100

print("Scholarship Percentage =", percentage, "%")
print("Congratulations!")
# Out:
# Scholarship Percentage = 75.0 %
# Congratulations!

# %%
favorite_color = "Blue"

print(favorite_color)
# Out:
# Blue

# %%
a = 10
b = 20

sum = a + b

print("Sum =", sum)
# Out:
# Sum = 30

# %%
length = 10
width = 5

area = length * width

print("Area =", area)
# Out:
# Area = 50

# %%
num = 15

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
a = 10
b = 20
c = 30

average = (a + b + c) / 3

print("Average =", average)
# Out:
# Average = 20.0

# %%
import math

radius = 7

area = math.pi * radius * radius

print("Area =", area)
# Out:
# Area = 153.93804002589985

# %%
text = "Python"

if len(text) > 6:
    print("More than 6 characters")
else:
    print("6 or fewer characters")
# Out:
# 6 or fewer characters

# %%
num1 = 15
num2 = 25

if num1 > num2:
    print(num1)
else:
    print(num2)
# Out:
# 25

# %%
total_marks = 500
obtained_marks = 400

percentage = (obtained_marks / total_marks) * 100

print("Percentage =", percentage, "%")
# Out:
# Percentage = 80.0 %
